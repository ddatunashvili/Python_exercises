# %% [markdown]
# ## შექმენი შემდეგი სტრუქტურები oop პრინციპების გამოყენებით
#
# თითოეული uppercase კლასს ჰქონდეს შესაბამისი lowercase ფუნქცია, რომელსაც ექნება return "კლასის სახელი"
# ```python
# class T:
#     def t(self):
#         return "class T"
# ```

# %% [markdown]
# <img src="https://i.imgur.com/myAKNSf.png">

# %%
#__start__

#__end__

# %% [markdown]
# <img src="https://i.imgur.com/ePT7Hdj.png">

# %%
#__start__

#__end__

# %% [markdown]
# <img src="https://i.imgur.com/MrFIFqw.png">

# %%
#__start__

#__end__
