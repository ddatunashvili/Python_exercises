# %% [markdown]
# ## ფეხბურთის სტატისტიკა
#
# * პითონით მონაცემების წაკითხვა და გაანალიზება: შერეული მონაცემთა ტიპების დამუშავება და მონაცემების გასუფთავება.
# * გამოთვალეთ მოგების პროცენტები: გამოთვალეთ მოგების პროცენტი თითოეული გუნდისთვის.
# * საუკეთესო გუნდების იდენტიფიცირება: იპოვეთ საუკეთესო 3 გუნდი ყველაზე მაღალი მოგების პროცენტით.
# * ცუდი გუნდების იდენტიფიცირება: იპოვეთ გუნდები, სადაც წაგების რაოდენობა აღემატება როგორც მოგებებს, ასევე ფრეებს.
# * მონაცემების შენახვა: შეინახეთ კარგი და ცუდი გუნდების მონაცემები xlsx, csv, ან txt ფაილში. მაგ: stats.xlsx
