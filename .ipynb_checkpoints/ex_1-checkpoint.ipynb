# %% [markdown]
# # 1
# დაწერე ფუნქცია, რომელიც სიიდან გააქრობს დუპლიკატებს
#
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
# * თუ გაიჭედე და ვერ აკეთებ, დაიხმარე python_lectures ან დამატებითი რესურსები
#
# მაგალითი:
#
# no_dub([3,3 23,4,5,2]) ➞ [2, 3, 4, 5]
#
# no_dub([3,2 2,1]) ➞ [1,2,3]
#
# no_dub([55,33,4,5,6,6]) ➞ [4,5,6,33,55]

# %%
#__start__




#__end__

# %% [markdown]
# # 2
# დაწერე ფუნქცია რომელიც დააბრუნებს 5 ს თუ ინტეჯერია n და თუ სტრინგია 4ს ოღონდ
#
# არ გამოიყენოთ არანაირი მათემატიკური მოქმედების ნიშანი არც არანაირი რიცხვი
#
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
# * თუ გაიჭედე და ვერ აკეთებ, დაიხმარე python_lectures ან დამატებითი რესურსები
#
# მაგალითი:
#
# five("ასდ") ➞ 4
#
# five(123) ➞ 5
#
# five(3)➞ 5

# %%
#__start__





#__end__
# Out:
# 5

# %% [markdown]
# # 3
#
# მოცემულია სახელები და გვარები:
#
# names = ["გელა","ბელა","ჰელა"]
#
# surnames = ["ნიუტონი","შტაიგერი","ცვაიგერი"]
#
# გააერთიანე ორივე სია ისე რომ სახელს თუ მივაწვდით ფუნქციას გვარი დააბრუნოს
#
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
# * თუ გაიჭედე და ვერ აკეთებ, დაიხმარე python_lectures ან დამატებითი რესურსები
#
# მაგალითი:
#
# surname("გელა") ➞ "ნიუტონი"
#
# surname("ბელა") ➞  "შტაიგერი"
#
# surname("ჰელა") ➞"ცვაიგერი"

# %%
#__start__






#__end__

# %% [markdown]
# # 4
#
# მოცემულია ენა და მისი განმარტებები:
#
# lang = {"ა":"*",  "ე":"/",  "ი":"^",  "ო":"&",  "უ":"@",  "მ":",,",  "შ":"ლ",  "ფ":"ყ",  "გ":"ოლ",  "ყ":"ფ"}
#
# დაწერე ფუნქცია, რომელიც განმარტებებს შეატრიალებს სიტყვებად და გადათარგმნის ტექსტს
#
# * ბევრი არ იფიქრო ამოცანაზე, არ უნდა იყოს რთული
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
# * თუ გაიჭედე და ვერ აკეთებ, დაიხმარე python_lectures ან დამატებითი რესურსები
#
#
# მაგალითი:
#
# translate("ლ/ნ რ&,, ოლოლ&ნ^* კ*ტ* ლ&,,^*, კ*ტ*ც დ* ლ&,,^ც /რთ^ ცხ&ვ/ლ^*")
#
# translate("/ს ლ/ლ* ს*ლ*ს^*, @ფრ&სწ&რ*დ ^ფ& ს*ნ*,, *^ *^ ხ&,, ხვდ/ბ^..")
#
# translate("^ფ& დ* *რ* ^ფ& ოლვ/ლ^, ^ნდ&/ლ,,* ,,*@ოლლ^,,, რ&,,/ლ^ც ს*ქ*რთვ/ლ&დ*ნ ^ფ& ,,*,,^ს ,,ხრ^დ*ნ, *^ღ& დ* კ&,,პ^@ტ/რლ^ ჩ*ტ/ნ*. *ს/ ლ/^ქ,,ნ* პ*^თ&ნ^")

# %%
#__start__





#__end__

# %% [markdown]
# # 5
# მოცემულია ორი სეტი და ორივე სეტიდან მხოლოდ ის მნიშვნელობები ამოიღოს,
# მაპიდან ერთმანეთს შეესამება
#
# ```python
#     value_map  = {1:3, 3:4, 4:5, 5:10}
#     a = {1,2,7,4,5}
#     b = {3,4,5,6}
# ```
# მაგ:
#
#
#
#
# * პასუხი რომელსაც დააბრუნებს უნდა იყოს დამრგვალებული მეათედებამდე (40.5)
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
# * თუ გაიჭედე და ვერ აკეთებ, დაიხმარე python_lectures ან დამატებითი რესურსები
#
#
# მაგალითი:
#
# dis(1500, 50) ➞ 750
#
# dis(89, 20) ➞ 71.2
#
# dis(100, 75) ➞ 25

# %%
#__start__

def dis(price, discount):


    return 


print(dis(1500, 50))




#__end__
# Out:
# None

# %% [markdown]
# # 6
#
# შექმენით ფუნქცია, რომელიც არგუმენტად იღებს ასაკს წლებში და აბრუნებს ასაკს დღეებში
#
# * გამოიყენე 365 დღე, როგორც წელიწადში დღეების რაოდენობა
# * მხოლოდ დადებითი რიცხვები იქნება არგუმენტებად და არ გაართულო
#
# მაგალითი:
#
# calc_age(65) ➞ 23725
#
# calc_age(0) ➞ 0
#
# calc_age(20) ➞ 7300

# %%
#__start__


def calc_age(age):


     return


print(calc_age(65))



#__end__

# %% [markdown]
# # 7
#
# შექმენით ფუნქცია,რომელიც მიიღებს სტრინგს და დააბრუნებს, როგორც ინტეჯერს
#
# * ყველა რიცხვი იქნება მთელი  და დადებითი
#
# მაგალითი:
#
# string_int("6") ➞ 6
#
# string_int("1000") ➞ 1000
#
# string_int("12") ➞ 12

# %%
#__start__



def string_int(string):

    return


print(string_int("6"))

#__end__

# %% [markdown]
# # 8
# შექმენით ფუნქცია რომელიც იღებს სიგრძეს (length)და სიგანეს (width) და ითვლის მართკუთხედის პერიმეტრს
#
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
# * თუ გაიჭედე და ვერ აკეთებ, დაიხმარე python_lectures ან დამატებითი რესურსები
#
# მაგალითი:
#
# find_perimeter(6, 7) ➞ 26
#
# find_perimeter(20, 10) ➞ 60
#
# find_perimeter(2, 9) ➞ 22

# %%
#__start__

def find_perimeter(length, width):

    return 


print(find_perimeter(6,7))

#__end__

# %% [markdown]
# # 9
# Ana-მ დაწერა ფუნქცია, რომელიც ესალმება მომხმარებლებებს. როგორც გაირკვა ის შეყვარებულია Murtaz-ზე და ის განსხვავებულად ესალმება მას. მან დაამატე სპეციალურად მისთვის კოდში ფუნქცია, მაგრამ შეცდომა დაუშვა.
#
# * წაიკითხე ყურადღებით მოცემულობა
# * არ იფიქრო ბევრი, არ უნდა იყოს რთულად დაწერილი
#
# მაგალითი:
#
# greeting("Nika") ➞ "Hello, Nika!"
#
# greeting("Lela") ➞ "Hello, Lela!"
#
# greeting("Murtaz") ➞ "Hello, my Love!"

# %%
#__start__

def greeting(name):
    return "Hello, " + name + "!"
    if name == "Murtaz":
        return "Hello, my Love!"


#__end__

# %% [markdown]
# # 10
#
#
# 	ენაბლუ ფუნქცია
#
# დაწერეთ ფუნქცია, რომელიც აბლუებს სიტყვას ისე თითქოს კითხვა უჭირს ნაწერის. ასოები განმეორებულია ორჯერ და გამოყოფილია წერტილებით
# "..." და სფეისით " " მიყოლებით. ბოლოში კი კითხვის ნიშანი აქვს სიტყვას "?"
#
# * ყველა შეყვანილი ტექსტი არის პატარა ასოებით (lower case)  და სულ მცირე ორი სიმბოლოსგან შედგება
#
#
# მაგალითი:
#
# stutter("incredible") ➞ "in... in... incredible?"
#
# stutter("enthusiastic") ➞ "en... en... enthusiastic?"
#
# stutter("outstanding") ➞ "ou... ou... outstanding?"

# %%
#__start__

def stuter(text):

    return



print(stuter("incredible"))

#__end__
# Out:
# None
