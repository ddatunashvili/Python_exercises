# %% [markdown]
# # 1
# დაწერე ფუნქცია, რომელიც მიიღებს რიცხვს და დააბრუნებს <br> n ხარისხში აყვანილს
#
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
#
#
# მაგალითი:
#
# po(4,2) ➞ 16
#
# po(-10,-1) ➞ -0.1
#
# po(1001,2) ➞ 1002001

# %%
#__start__



#__end__

# %% [markdown]
# # 2
# დაწერე ფუნქცია, რომელიც მიიღებს სიას და დააბრუნებს შესაბამის dict _ ს
#
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
#
# მაგალითი:
#
#
# tod( [1, "a", 2, "b" ] ) ➞ {1: "a", 2: "b"}
# <br><br>
# tod( ["Gela", "Nugzarishvili", "Tengiz", "Murmanishvili" ] ) ➞ { "Gela": "Nugzarishvili", "Tengiz": "Murmanishvili" }
# <br><br>
# tod( [ "David", 10, "Tornike", 100 ] ) ➞ { "David":10, "Tornike": 100}

# %%
#__start__


#__end__

# %%
#__start__


#__end__

# %% [markdown]
# # 4
# დაწერე ფუნქცია, რომელიც მიიღებს ტექსტს. <br>ტექსტში ყოველი ასო ინდექსით გადაწეულია მარჯვნივ .<br>თქვენ უნდა დაწეროთ დეკრიპტორი ფუნქცია რომელიც უკან გადმოწევს ასოებს
#
# * შეგიძლიათ გამოიყენოთ index() ფუნქცია
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
#
# <br>
# alph = "abcdefghijklmnopqrstuvwxyz"<br>
# მაგალითი:
#
# decrypt("fcxkf") ➞"david"
#
# decrypt("gctvj") ➞ "earth"
#
# decrypt("uwu") ➞ "sus"

# %%
#__start__


#__end__

# %% [markdown]
# # 5
#
# დაწერე ფუნქცია, რომელიც მიიღებს ცვლად data ს, tuple ტიპის  მონაცემთა სტრუქტურას და დაფორმატებს შემდეგნაირაირად:
#
# ```python
#   # მონაცემების დაფორმატება
#    data = (1,2,3,4,5)
#    formated_data = (1,5,2,4,3)
#    #(1,5,2,4,3) - (პირველი,ბოლო, მეორე,ბოლოსწინა,მესამე .....)
# ```
#
# * result უნდა იყოს str რომლის character ები უნდა იყოს მძიმით გამოყოფილი
# * ყურადღებით წაიკითხეთ მოცემულობა
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
# * თუ კოდი არ ეშვება წაშალეთ
#
# მაგალითი:
#
# fdata( ( 1, 2, 3, 4, 5 ) ) ➞ "1,5,2,4,3"
#
# fdata( ( 4, 6, 6, 8, 8, 8) ) ➞ "4,8,6,8,6,8"
#
# fdata( ( 1, "a", "a", 0, "a", 0) ) ➞ "1,0,a,a,a,0"

# %%
#__start__


#__end__
