# %% [markdown]
# # 1
#
# დაწერეთ ფუნქცია, რომელიც ამოიღებს სიიდან ყველაზე დიდ რიცხვს. ამოიღებს ყველაზე პატარა რიცხვს და გამოითვლის ამ რიცხვების ნამრავლს
#
# * არ გამოიყენოთ max() min() ფუნქციები
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
#
# მაგალითი:
#
# min_max([-1, 3, 5, 6, 99, 12, 2]) ➞ -99
#
# min_max([0, 12, 4, 87]) ➞ 0
#
# min_max([8,2,10]) ➞ 20

# %%
#__start__

#__end__

# %% [markdown]
# # 2
#
# დაწერეთ ფუნქცია, რომელიც დააბრუნებს სიაში ნაპოვნ float ს
#
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
# * თუ გაიჭედე და ვერ აკეთებ, დაიხმარე ლექციები ან დამატებითი რესურსები
#
# მაგალითი:
#
# find_float([-1, 3, 50.2, 6, 99, 12, 2]) ➞ 50.2
#
# find_float([0, 12, 4, 0.0, 87]) ➞ 0.0
#
# find_float([0, 12, 4, 0.99, 87]) ➞ 0.99

# %%
#__start__


#__end__

# %% [markdown]
# # 3
#
# დაწერეთ ფუნქცია, რომელიც დააბრუნებს სიას ან სიებს რომელშიც True არის<br> სხვა შემთხვევაში ჩაანაცვლოს 0-ით
#
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
# * თუ გაიჭედე და ვერ აკეთებ, დაიხმარე ლექციები ან დამატებითი რესურსები
#
# მაგალითი:
#
# find_true([0, True])    ➞ [[0, True]]
#
# find_true( [0,"Yes", 87], [0,0,3] )   ➞ [0, 0]
#
# find_true( [1, True], [3], [4,True] )   ➞ [[1, True], 0, [4, True]]

# %%
#__start__


#__end__

# %% [markdown]
# # 4
#
# დაწერეთ ფუნქცია, რომელიც ამოიღებს 10 დან 55 მდე რიცხვებს სიიდან და იპოვის მათ შორის უდიდესს
#
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
# * თუ გაიჭედე და ვერ აკეთებ, დაიხმარე ლექციები ან დამატებითი რესურსები
#
# მაგალითი:
#
# max_range([11,12,13]) ➞ 13
#
# max_range([0, 12, 4, 87]) ➞ 12
#
# max_range([1, 1, 14, 50, 20, 49]) ➞ 50

# %%
#__start__


#__end__

# %% [markdown]
# # 5
#
# დაწერეთ ფუნქცია, რომელიც სტრინგიდან ამოიღებს "["  "]"   შორის ტექსტებს
#
#
#
#
# * არ გამოიყენოთ re (regular expression) (return)
# * არ დაგავიწყდეს შედეგის დაბრუნება  (return)
# * თუ გაიჭედე და ვერ აკეთებ, დაიხმარე ლექციები ან დამატებითი რესურსები
#
# მაგალითი:
#
# trimmer("aasdkmsal]kmd[კატა]0as[dasdj") ➞ "კატა"
#
# trimmer("1223]34[ძაღლი]12[დათვი]") ➞ "ძაღლიდათვი"
#
# trimmer("asdasdasd[გველი]asd[3245") ➞ "გველი"

# %%
#__start__

#__end__
